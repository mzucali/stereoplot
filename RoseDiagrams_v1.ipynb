# %% [markdown]
# <a href="https://colab.research.google.com/github/mzucali/stereoplot/blob/main/RoseDiagrams_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load DATA FILE EXCEL
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-60e57939-1af4-42ec-b897-411fa12ef1ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60e57939-1af4-42ec-b897-411fa12ef1ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: i need a code for rose diagram also called petal diagram to plot data read from excel file containing columns with strike and dip

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming your excel file is named 'data.xlsx' and has columns 'strike' and 'dip'
# Replace 'data.xlsx' with your actual file name
#data = pd.read_excel('data.xlsx')

# Extract strike and dip values
#strike = data['strike'].values
#dip = data['dip'].values

strike = [12, 23, 34, 45, 56, 67,78]
dip = [2, 3,4 ,5,5,3,6]


# Convert strike to radians (0-2*pi)
strike_rad = np.deg2rad(strike)

# Create a rose diagram (petal diagram)
n_bins = 36  # Number of bins for the rose diagram
bin_width = 2 * np.pi / n_bins

# Calculate the frequencies of strike directions in each bin
hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi))

# Plot the rose diagram
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
ax.bar(angles, hist, width=bin_width, bottom=0.0, color='blue', alpha=0.7)

# Customize the plot
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title('Rose Diagram of Strike Directions')
plt.show()

# %%
# prompt: add weight to length values

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Assuming your excel file is named 'data.xlsx' and has columns 'strike' and 'dip'
# Replace 'data.xlsx' with your actual file name
#data = pd.read_excel('data.xlsx')

# Extract strike and dip values
#strike = data['strike'].values
#dip = data['dip'].values

strike = [12, 23, 34, 45, 56, 67,78]
dip = [2, 3,4 ,5,5,3,6]


# Convert strike to radians (0-2*pi)
strike_rad = np.deg2rad(strike)

# Create a rose diagram (petal diagram)
n_bins = 36  # Number of bins for the rose diagram
bin_width = 2 * np.pi / n_bins

# Calculate the frequencies of strike directions in each bin
# Add weight to length values
weights = dip  # Assuming 'dip' represents the length or weight

hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi), weights=weights)

# Plot the rose diagram
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
ax.bar(angles, hist, width=bin_width, bottom=0.0, color='blue', alpha=0.7)

# Customize the plot
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title('Rose Diagram of Strike Directions with Length Weighting')
plt.show()

# %%
# prompt: differentiate groups by column group and use different colours

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
data = {'group': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
        'strike': [12, 23, 34, 45, 56, 67, 78, 89, 90],
        'dip': [2, 3, 4, 5, 5, 3, 6, 7, 8]}
df = pd.DataFrame(data)

# Define colors for each group
colors = {'A': 'blue', 'B': 'green', 'C': 'red'}

# Create a rose diagram for each group
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

for group, group_data in df.groupby('group'):
  strike = group_data['strike'].values
  dip = group_data['dip'].values

  strike_rad = np.deg2rad(strike)

  n_bins = 36
  bin_width = 2 * np.pi / n_bins

  hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi), weights=dip)

  angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
  ax.bar(angles, hist, width=bin_width, bottom=0.0, color=colors[group], alpha=0.7, label=group)

# Customize the plot
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title('Rose Diagram of Strike Directions by Group')
ax.legend()
plt.show()

# %%
# prompt: differentiate groups by column group and use different colours in different figures

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
data = {'group': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
        'strike': [12, 23, 34, 45, 56, 67, 78, 89, 90],
        'dip': [2, 3, 4, 5, 5, 3, 6, 7, 8]}
df = pd.DataFrame(data)

# Define colors for each group
colors = {'A': 'blue', 'B': 'green', 'C': 'red'}

# Create a rose diagram for each group
for group, group_data in df.groupby('group'):
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

    strike = group_data['strike'].values
    dip = group_data['dip'].values

    strike_rad = np.deg2rad(strike)

    n_bins = 36
    bin_width = 2 * np.pi / n_bins

    hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi), weights=dip)

    angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
    ax.bar(angles, hist, width=bin_width, bottom=0.0, color=colors[group], alpha=0.7, label=group)

    # Customize the plot
    ax.set_theta_zero_location('N')
    ax.set_theta_direction(-1)
    ax.set_title(f'Rose Diagram of Strike Directions for Group {group}')
    ax.legend()
    plt.show()

# %%
# prompt: salva le figure in formato raster

from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# load DATA FILE EXCEL
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))


# Assuming your excel file is named 'data.xlsx' and has columns 'strike' and 'dip'
# Replace 'data.xlsx' with your actual file name
#data = pd.read_excel('data.xlsx')

# Extract strike and dip values
#strike = data['strike'].values
#dip = data['dip'].values

strike = [12, 23, 34, 45, 56, 67,78]
dip = [2, 3,4 ,5,5,3,6]


# Convert strike to radians (0-2*pi)
strike_rad = np.deg2rad(strike)

# Create a rose diagram (petal diagram)
n_bins = 36  # Number of bins for the rose diagram
bin_width = 2 * np.pi / n_bins

# Calculate the frequencies of strike directions in each bin
hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi))

# Plot the rose diagram
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
ax.bar(angles, hist, width=bin_width, bottom=0.0, color='blue', alpha=0.7)

# Customize the plot
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title('Rose Diagram of Strike Directions')
plt.savefig('rose_diagram_1.png', dpi=300) # Save as PNG
plt.show()




# Assuming your excel file is named 'data.xlsx' and has columns 'strike' and 'dip'
# Replace 'data.xlsx' with your actual file name
#data = pd.read_excel('data.xlsx')

# Extract strike and dip values
#strike = data['strike'].values
#dip = data['dip'].values

strike = [12, 23, 34, 45, 56, 67,78]
dip = [2, 3,4 ,5,5,3,6]


# Convert strike to radians (0-2*pi)
strike_rad = np.deg2rad(strike)

# Create a rose diagram (petal diagram)
n_bins = 36  # Number of bins for the rose diagram
bin_width = 2 * np.pi / n_bins

# Calculate the frequencies of strike directions in each bin
# Add weight to length values
weights = dip  # Assuming 'dip' represents the length or weight

hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi), weights=weights)

# Plot the rose diagram
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
ax.bar(angles, hist, width=bin_width, bottom=0.0, color='blue', alpha=0.7)

# Customize the plot
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title('Rose Diagram of Strike Directions with Length Weighting')
plt.savefig('rose_diagram_2.png', dpi=300) # Save as PNG
plt.show()


# Sample data (replace with your actual data)
data = {'group': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
        'strike': [12, 23, 34, 45, 56, 67, 78, 89, 90],
        'dip': [2, 3, 4, 5, 5, 3, 6, 7, 8]}
df = pd.DataFrame(data)

# Define colors for each group
colors = {'A': 'blue', 'B': 'green', 'C': 'red'}

# Create a rose diagram for each group
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

for group, group_data in df.groupby('group'):
  strike = group_data['strike'].values
  dip = group_data['dip'].values

  strike_rad = np.deg2rad(strike)

  n_bins = 36
  bin_width = 2 * np.pi / n_bins

  hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi), weights=dip)

  angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
  ax.bar(angles, hist, width=bin_width, bottom=0.0, color=colors[group], alpha=0.7, label=group)

# Customize the plot
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title('Rose Diagram of Strike Directions by Group')
ax.legend()
plt.savefig('rose_diagram_3.png', dpi=300) # Save as PNG
plt.show()


# Sample data (replace with your actual data)
data = {'group': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
        'strike': [12, 23, 34, 45, 56, 67, 78, 89, 90],
        'dip': [2, 3, 4, 5, 5, 3, 6, 7, 8]}
df = pd.DataFrame(data)

# Define colors for each group
colors = {'A': 'blue', 'B': 'green', 'C': 'red'}

# Create a rose diagram for each group
for group, group_data in df.groupby('group'):
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

    strike = group_data['strike'].values
    dip = group_data['dip'].values

    strike_rad = np.deg2rad(strike)

    n_bins = 36
    bin_width = 2 * np.pi / n_bins

    hist, bin_edges = np.histogram(strike_rad, bins=n_bins, range=(0, 2 * np.pi), weights=dip)

    angles = np.deg2rad(np.linspace(0, 360, n_bins, endpoint=False))
    ax.bar(angles, hist, width=bin_width, bottom=0.0, color=colors[group], alpha=0.7, label=group)

    # Customize the plot
    ax.set_theta_zero_location('N')
    ax.set_theta_direction(-1)
    ax.set_title(f'Rose Diagram of Strike Directions for Group {group}')
    ax.legend()
    plt.savefig(f'rose_diagram_group_{group}.png', dpi=300) # Save as PNG
    plt.show()
# Out:
#      <input type="file" id="files-b4cbda9e-8886-4b07-bc12-ab08f102e768" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4cbda9e-8886-4b07-bc12-ab08f102e768">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
